# %% [markdown]
# <a href="https://colab.research.google.com/github/deepluckyperson/sber_homework/blob/main/%D0%94%D0%97_3_2_%D0%BF%D1%80%D0%BE%D0%BC%D0%B5%D0%B6%D1%83%D1%82%D0%BE%D1%87%D0%BD%D0%BE%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Домашнее задание. Часть 2.
#
#
# Вего за эту часть ДЗ можно набрать максимум **8.5 баллов**. Разбиение баллов по каждой из задач представлено непосредственно перед текстом каждой задачи.
#
# **Дедлайн - пятница, 11.12.2020 в 23:59.**
#
# Дедлайн жесткий, сдача после дедлайна - 0 баллов за ДЗ.
#
# Ссылка на ноутбук в колабе: https://colab.research.google.com/drive/18Yom8NjCpK0XAVaO6-RzNs9--foqKtio?usp=sharing
#
# В этой части ДЗ Вам необходимо будет работать с датасетами - все они лежат в репозитории курса, а именно https://github.com/ddvika/Data-Science-School-2020/tree/main/hw_intermediate в папке `"materials"`
#
# а также на гугл диске:
# https://drive.google.com/drive/folders/1mvcBvJ_2341foynNnvmkJh3EJdS4_b4m?usp=sharing
#
# Вы можете обойтись и без скачивания, тк все данные импортируются напрямую из гитхаб

# %% [markdown]
# # Задание 1
# файл 'file_example_XLSX_1000.xlsx' лежит в репозитории и на гугл диске по ссылке выше

# %% [markdown]
# **0.5 point**
#
# - убрать ненужный столбец Unnamed
#
# **0.5 point**
# - Отсортировать людей по возрасту
#
# **0.5 point**
# - разделить людей по полу (сохраните в переменные female, male)
#
# **1 point**
# - построить гистограмму возрастов для мужчин и гистограмму возрастов для женщин

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel('https://github.com/ddvika/Data-Science-School-2020/blob/main/hw_intermediate/materials/file_example_XLSX_1000.xlsx?raw=true')
#1
df1 = df.drop('Unnamed: 0', axis = 'columns')
print ('1 task', '\n',df1)
print()
#2
df2 = df1.sort_values(by=['Gender','Age'])
print ('2 task', '\n',df2)
#3
df_male = df2.loc[df2.Gender=='Male']
df_female = df2.loc[df2.Gender=='Female']
print('3 task', '\n')
print ('Male', '\n', df_male)
print ('Female', '\n', df_female)
print()
#4
print('4 task', '\n')
sns.distplot(a=df_male['Age'], label='Male', kde=False)
sns.distplot(a=df_female['Age'],label='Female', kde=False)
plt.legend()
# Out:
# 1 task
#      First Name   Last Name  Gender        Country  Age        Date    Id
# 0        Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1         Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2       Philip        Gent    Male         France   36  21/05/2015  2587
# 3     Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4      Nereida     Magwood  Female  United States   58  16/08/2016  2468
# ..         ...         ...     ...            ...  ...         ...   ...
# 995       Roma  Lafollette  Female  United States   34  15/10/2017  2654
# 996     Felisa        Cail  Female  United States   28  16/08/2016  6525
# 997   Demetria       Abbey  Female  United States   32  21/05/2015  3265
# 998     Jeromy        Danz    Male  United States   39  15/10/2017  3265
# 999   Rasheeda      Alkire  Female  United States   29  16/08/2016  6125
#
# [1000 rows x 7 columns]
#
# 2 task
#      First Name  Last Name  Gender        Country  Age        Date    Id
# 27   Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 77   Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 127  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 177  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 227  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# ..         ...        ...     ...            ...  ...         ...   ...
# 778      Garth      Gangi    Male  United States   41  16/08/2016  3256
# 828      Garth      Gangi    Male  United States   41  16/08/2016  3256
# 878      Garth      Gangi    Male  United States   41  16/08/2016  3256
# 928      Garth      Gangi    Male  United States   41  16/08/2016  3256
# 978      Garth      Gangi    Male  United States   41  16/08/2016  3256
#
# [1000 rows x 7 columns]
# 3 task
#
# Male
#      First Name Last Name Gender        Country  Age        Date    Id
# 24      Lester   Prothro   Male         France   21  15/10/2017  6574
# 74      Lester   Prothro   Male         France   21  15/10/2017  6574
# 124     Lester   Prothro   Male         France   21  15/10/2017  6574
# 174     Lester   Prothro   Male         France   21  15/10/2017  6574
# 224     Lester   Prothro   Male         France   21  15/10/2017  6574
# ..         ...       ...    ...            ...  ...         ...   ...
# 778      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 828      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 878      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 928      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 978      Garth     Gangi   Male  United States   41  16/08/2016  3256
#
# [240 rows x 7 columns]
# Female
#      First Name  Last Name  Gender        Country  Age        Date    Id
# 27   Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 77   Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 127  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 177  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 227  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# ..         ...        ...     ...            ...  ...         ...   ...
# 754    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 804    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 854    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 904    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 954    Nereida    Magwood  Female  United States   58  16/08/2016  2468
#
# [760 rows x 7 columns]
#
# 4 task
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Задание 2

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ddvika/Data-Science-School-2020/main/hw_intermediate/materials/appl_1980_2014.csv')
df
# Out:
#       Unnamed: 0        Date   Open   High    Low  Close     Volume  Adj Close
# 0              0  2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1              1  2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2              2  2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3              3  2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4              4  2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...         ...    ...    ...    ...    ...        ...        ...
# 8460        8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461        8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462        8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463        8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464        8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 8 columns]

# %% [markdown]
# **0.5 point**
# - убрать ненужный столбец Unnamed
#
# **0.5 point**
# - Проверьте тип данных в столбцах
#
# **0.5 point**
# - Преобразуйте столбец Date в тип datetime
#
# **0.5 point**
# - Установите дату в качестве индекса
#
# **0.5 point**
# - Есть ли повторяющиеся даты?
#
# **0.5 point**
# - Получите последний рабочий день каждого месяца
#
# **0.5 point**
# - Какая разница в днях между первым днем и самым давним?
#
# **0.5 point**
# - Сколько месяцев у нас есть в данных?
#
# **0.5 point**
# -  Постройте значение «Adj Close». Установите размер рисунка 13,5 х 9 дюймов.
#
# **Доп. задание (макс балл 1.5)**
# - Придумайте собственные вопросы и ответьте на них. Также можете нарисовать какие-то интересные графики.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#1
df1 = df.drop('Unnamed: 0', axis = 'columns')
print ('1 task', '\n',df1)
print()
#2
df2 = df1.dtypes
print ('2 task','\n', df2)
print()
#3
df3 = df.astype({'Date': 'datetime64'})
print ('3 task','\n',df3.dtypes)
print()
#4
df4 = df1.set_index('Date')
print ('4 task','\n',df4)
print()
#5
df5 = df3 - df3.drop_duplicates('Date')
print('5 task','\n','дубликаты:', df5.Date.astype('int').any())
print()
#6

import re
from datetime import datetime
last_workday=[0 for i in range(0,8464)]
#Поиск дат 26-31
for i in range(0,8464):
  if re.match(r'\d\d\d\d-\d\d-31', str(df1['Date'][i])):
    last_workday[i]=str(df1['Date'][i])
  elif re.match(r'\d\d\d\d-\d\d-30', str(df1['Date'][i])):
    last_workday[i]=str(df1['Date'][i])
  elif re.match(r'\d\d\d\d-\d\d-29', str(df1['Date'][i])):
    last_workday[i]=str(df1['Date'][i])
  elif re.match(r'\d\d\d\d-\d\d-28', str(df1['Date'][i])):
    last_workday[i]=str(df1['Date'][i])
  elif re.match(r'\d\d\d\d-\d\d-27', str(df1['Date'][i])):
    last_workday[i]=str(df1['Date'][i])
  elif re.match(r'\d\d\d\d-\d\d-26', str(df1['Date'][i])):
    last_workday[i]=str(df1['Date'][i])
#Очистка от 0
for i in range(0,8464):
  if 0 in last_workday:
      last_workday.remove(0)
i=0
while (len(last_workday)>int(int(str(df3.Date[0]-df3.Date[8464])[0:5])/((365*3+366)/(12*4)))+1):
  if (datetime.strptime(last_workday[i], "%Y-%m-%d").year == datetime.strptime(last_workday[i+1], "%Y-%m-%d").year) and (datetime.strptime(last_workday[i], "%Y-%m-%d").month == datetime.strptime(last_workday[i+1], "%Y-%m-%d").month):
    last_workday.pop(i+1)
    i=i-1
  i=i+1
print('6 task','\n', last_workday)

#7
df6 = df3.Date[0]-df3.Date[8464]
print ('7 task','\n',df6)
print()
#8
df7 = int(int(str(df3.Date[0]-df3.Date[8464])[0:5]) / ((365*3+366)/(12*4)))
print ('8 task','\n',df7)
print()
#9
print('9 task','\n')
sns.set(rc={'figure.figsize':(13.5,9)})
sns.distplot(df['Adj Close'], kde = False)
plt.show()
# Out:
# 1 task
#              Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]
#
# 2 task
#  Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object
#
# 3 task
#  Unnamed: 0             int64
# Date          datetime64[ns]
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume                 int64
# Adj Close            float64
# dtype: object
#
# 4 task
#               Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]
#
# 5 task
#  дубликаты: False
#
# 6 task
#  ['2014-06-30', '2014-05-30', '2014-04-30', '2014-03-31', '2014-02-28', '2014-01-31', '2013-12-31', '2013-11-29', '2013-10-31', '2013-09-30', '2013-08-30', '2013-07-31', '2013-06-28', '2013-05-31', '2013-04-30', '2013-03-28', '2013-02-28', '2013-01-31', '2012-12-31', '2012-11-30', '2012-10-31', '2012-09-28', '2012-08-31', '2012-07-31', '2012-06-29', '2012-05-31', '2012-04-30', '2012-03-30', '2012-02-29', '2012-01-31', '2011-12-30', '2011-11-30', '2011-10-31', '2011-09-30', '2011-08-31', '2011-07-29', '2011-06-30', '2011-05-31', '2011-04-29', '2011-03-31', '2011-02-28', '2011-01-31', '2010-12-31', '2010-11-30', '2010-10-29', '2010-09-30', '2010-08-31', '2010-07-30', '2010-06-30', '2010-05-28', '2010-04-30', '2010-03-31', '2010-02-26', '2010-01-29', '2009-12-31', '2009-11-30', '2009-10-30', '2009-09-30', '2009-08-31', '2009-07-31', '2009-06-30', '2009-05-29', '2009-04-30', '2009-03-31', '2009-02-27', '2009-01-30', '2008-12-31', '2008-11-28', '2008-10-31', '2008-09-30', '2008-08-29', '2008-07-31', '2008-06-30', '2008-05-30', '2008-04-30', '2008-03-31', '2008-02-29', '2008-01-31', '2007-12-31', '2007-11-30', '2007-10-31', '2007-09-28', '2007-08-31', '2007-07-31', '2007-06-29', '2007-05-31', '2007-04-30', '2007-03-30', '2007-02-28', '2007-01-31', '2006-12-29', '2006-11-30', '2006-10-31', '2006-09-29', '2